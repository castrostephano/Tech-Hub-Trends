# %%
import pandas as pd

# %%
austin_csv_path = "Resources/Austin_Crime.csv"

# %%
#import the data into a pandas dataframe

crime_df = pd.read_csv(austin_csv_path)
crime_df
# Out:
#          Incident Number     Highest Offense Description  \
# 0              201012121              FAMILY DISTURBANCE
# 1              201010159              FAMILY DISTURBANCE
# 2              201012437   AGG ASSAULT FAM/DATE VIOLENCE
# 3            20135001226                  IDENTITY THEFT
# 4              201010801             PUBLIC INTOXICATION
# ...                  ...                             ...
# 1213133        202020693             BURGLARY OF VEHICLE
# 1213134        202012015  ASSAULT W/INJURY-FAM/DATE VIOL
# 1213135       2020540578     AGG ASLT STRANGLE/SUFFOCATE
# 1213136        202011513  DISCLOSE/PROMO INTIMATE VISUAL
# 1213137      20205001615                           THEFT
#
#          Highest Offense Code Family Violence      Occurred Date Time  \
# 0                        3400               N  01/01/2010 06:00:00 PM
# 1                        3400               N  01/01/2010 12:27:00 PM
# ...

# %%
# Set new index to Date of Occurrence
df = crime_df.set_index("Report Date")
df.head()
# Out:
#              Incident Number    Highest Offense Description  \
# Report Date
# 01/01/2010         201012121             FAMILY DISTURBANCE
# 01/01/2010         201010159             FAMILY DISTURBANCE
# 01/01/2010         201012437  AGG ASSAULT FAM/DATE VIOLENCE
# 01/09/2013       20135001226                 IDENTITY THEFT
# 01/01/2010         201010801            PUBLIC INTOXICATION
#
#              Highest Offense Code Family Violence      Occurred Date Time  \
# Report Date
# 01/01/2010                   3400               N  01/01/2010 06:00:00 PM
# 01/01/2010                   3400               N  01/01/2010 12:27:00 PM
# 01/01/2010                    402               Y  01/01/2010 08:57:00 PM
# 01/09/2013                   4022               N  01/01/2010 09:24:00 AM
# 01/01/2010                   2300               N  01/01/2010 03:20:00 AM
#
#             Occurred Date  Occurred Time        Report Date Time  Report Time  \
# Report Date
# ...

# %%
date_loc = df.loc[:, ["Latitude", "Longitude"]].head()
date_loc
# Out:
#               Latitude  Longitude
# Report Date
# 01/01/2010   30.224783 -97.694979
# 01/01/2010   30.233996 -97.692674
# 01/01/2010   30.224943 -97.755393
# 01/09/2013   30.283700 -97.715460
# 01/01/2010   30.219775 -97.700376
