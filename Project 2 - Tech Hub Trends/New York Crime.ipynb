# %%
import pandas as pd

# %%
nyc_csv_path = "Resources/NYC_Crime.csv"

# %%
#import the data into a pandas dataframe

crime_df = pd.read_csv(nyc_csv_path)
crime_df
# Out:
# /Users/stephanocastro/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         338706544   12/27/2019     11:55:00   12/27/2019     12:03:00
# 1         782334409   12/29/2019     21:00:00   12/30/2019     08:00:00
# 2         380753775   12/26/2019     14:58:00   12/29/2019     11:30:00
# 3         961278646   12/27/2019     01:37:00   12/27/2019     01:49:00
# 4         466248043   12/27/2019     00:16:00   12/27/2019     00:18:00
# ...             ...          ...          ...          ...          ...
# 1485764   766112675   11/06/2017     12:00:00   07/29/2019     18:00:00
# 1485765   132368442   07/11/2018     09:50:00   07/11/2019     10:35:00
# ...

# %%
crime_df.count()
# Out:
# CMPLNT_NUM           1485769
# CMPLNT_FR_DT         1485769
# CMPLNT_FR_TM         1485769
# CMPLNT_TO_DT         1226631
# CMPLNT_TO_TM         1227194
# ADDR_PCT_CD          1485575
# RPT_DT               1485769
# KY_CD                1485769
# OFNS_DESC            1485352
# PD_CD                1482104
# PD_DESC              1482104
# CRM_ATPT_CPTD_CD     1485768
# LAW_CAT_CD           1485769
# BORO_NM              1481506
# LOC_OF_OCCUR_DESC    1163350
# PREM_TYP_DESC        1476625
# JURIS_DESC           1485769
# PARKS_NM                9134
# HADEVELOPT             60032
# X_COORD_CD           1482483
# Y_COORD_CD           1482483
# Latitude             1482483
# Longitude            1482483
# Lat_Lon              1482483
# dtype: int64

# %%
# Set new index to Date of Occurrence
df = crime_df.set_index("CMPLNT_TO_DT")
df.head()
# Out:
#               CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_TM  ADDR_PCT_CD  \
# CMPLNT_TO_DT
# 12/27/2019     338706544   12/27/2019     11:55:00     12:03:00         79.0
# 12/30/2019     782334409   12/29/2019     21:00:00     08:00:00         75.0
# 12/29/2019     380753775   12/26/2019     14:58:00     11:30:00         76.0
# 12/27/2019     961278646   12/27/2019     01:37:00     01:49:00         79.0
# 12/27/2019     466248043   12/27/2019     00:16:00     00:18:00        104.0
#
#                   RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# CMPLNT_TO_DT
# 12/27/2019    12/27/2019    106                  FELONY ASSAULT  109.0
# 12/30/2019    12/30/2019    107                        BURGLARY  233.0
# 12/29/2019    12/29/2019    109                   GRAND LARCENY  433.0
# 12/27/2019    12/27/2019    118               DANGEROUS WEAPONS  793.0
# 12/27/2019    12/27/2019    121  CRIMINAL MISCHIEF & RELATED OF  267.0
#
# ...

# %%
date_loc = df.loc[:, ["Lat_Lon"]].head()
date_loc
# Out:
#                                               Lat_Lon
# CMPLNT_TO_DT
# 12/27/2019    (40.67992231900007, -73.94076886699997)
# 12/30/2019    (40.68577092000004, -73.88014489399995)
# 12/29/2019    (40.67269624900007, -74.01172482699997)
# 12/27/2019    (40.69122747200004, -73.93968063699998)
# 12/27/2019    (40.70742009400004, -73.91547119899997)
